# %% [markdown]
# <a href="https://colab.research.google.com/github/zen-zap/pheno_crop/blob/main/Pheno_Crop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pheno Crop
#
# Detection of crop growth stage from satellite imagery

# %% [markdown]
# # Setup GEE and authenticate

# %%
# @title
# GEE setup
import ee

ee.Authenticate()
from google.colab import userdata
PROJECT_ID = userdata.get('PROJECT_ID')

ee.Initialize(project=PROJECT_ID)
print("Earth Engine Initialized Successfully!")
print(PROJECT_ID)
# Out:
# Earth Engine Initialized Successfully!
# pheno-crop-489815

# %% [markdown]
# ## Scripts Setup

# %%
# @title
# %%writefile gee_index_fetcher.py

"""
GEE – Sentinel-2 Index Fetcher + Image Downloader
==================================================
Pulls vegetation indices AND downloads satellite images directly from
Google Earth Engine for any lat/lon location over a date range.

Image types available:
  rgb         -> True colour (B4, B3, B2)
  falsecolor  -> False colour NIR composite (B8, B4, B3)
  ndvi        -> NDVI heatmap (colourised, red to green)
  geotiff     -> Raw multi-band GeoTIFF (all S2 bands)

Export destinations:
  local       -> PNG/TIF saved to --image-dir on your machine
  drive       -> Exported to your Google Drive (async GEE task)
  both        -> Local + Drive
"""

import argparse
import os
import sys
import requests
from datetime import datetime, timedelta

# ==============================================================================
# GLOBAL CONFIGURATION
# ==============================================================================
DRIVE_EXPORT_FOLDER = "sentinel_2"  # Folder created at the root of Google Drive

# ──────────────────────────────────────────────────────────────────────────────
# INDEX REGISTRY
# ──────────────────────────────────────────────────────────────────────────────
INDEX_REGISTRY = {
    "NDVI":  ("(NIR - RED) / (NIR + RED)",                           ["B8", "B4"]),
    "EVI":   ("2.5 * (NIR - RED) / (NIR + 6*RED - 7.5*BLUE + 1)",   ["B8", "B4", "B2"]),
    "EVI2":  ("2.5 * (NIR - RED) / (NIR + 2.4*RED + 1)",            ["B8", "B4"]),
    "SAVI":  ("1.5 * (NIR - RED) / (NIR + RED + 0.5)",              ["B8", "B4"]),
    "MSAVI": ("(2*NIR + 1 - sqrt((2*NIR+1)**2 - 8*(NIR-RED))) / 2", ["B8", "B4"]),
    "GNDVI": ("(NIR - GREEN) / (NIR + GREEN)",                       ["B8", "B3"]),
    "NDRE":  ("(NIR - REDEDGE) / (NIR + REDEDGE)",                  ["B8", "B5"]),
    "NDWI":  ("(GREEN - NIR) / (GREEN + NIR)",                       ["B3", "B8"]),
    "NDMI":  ("(NIR - SWIR1) / (NIR + SWIR1)",                      ["B8", "B11"]),
    "NBR":   ("(NIR - SWIR2) / (NIR + SWIR2)",                      ["B8", "B12"]),
    "ARVI":  ("(NIR - (2*RED - BLUE)) / (NIR + (2*RED - BLUE))",    ["B8", "B4", "B2"]),
}
ALL_INDEX_NAMES = list(INDEX_REGISTRY.keys())

IMAGE_TYPES    = ["rgb", "falsecolor", "ndvi", "geotiff"]
EXPORT_TARGETS = ["local", "drive", "both"]

# NDVI colour ramp: red (bare/stressed) -> yellow -> green (healthy)
NDVI_PALETTE = [
    "#d73027", "#f46d43", "#fdae61", "#fee08b",
    "#ffffbf", "#d9ef8b", "#a6d96a", "#66bd63",
    "#1a9850", "#006837",
]


# ──────────────────────────────────────────────────────────────────────────────
# 1. ARGUMENT PARSING
# ──────────────────────────────────────────────────────────────────────────────

def parse_args():
    parser = argparse.ArgumentParser(
        description="Fetch Sentinel-2 indices + download images from GEE.",
        formatter_class=argparse.RawDescriptionHelpFormatter,
        epilog=__doc__,
    )
    parser.add_argument("--lat",   type=float, required=True, help="Latitude  (e.g. 25.5620).")
    parser.add_argument("--lon",   type=float, required=True, help="Longitude (e.g. 84.8720).")
    parser.add_argument("--start", required=True, help="Start date YYYY-MM-DD.")
    parser.add_argument("--end",   required=True, help="End date   YYYY-MM-DD.")
    parser.add_argument("--plot-id", required=True, type=str, help="The ID of the plot (e.g., 2).")
    parser.add_argument("--gap",   type=int, default=None,
                        help="Gap in days for composite windows. Omit = every scene.")
    parser.add_argument("--indices", nargs="+", default=ALL_INDEX_NAMES,
                        choices=ALL_INDEX_NAMES, metavar="INDEX",
                        help=f"Indices to compute. Default: all.")
    parser.add_argument("--buffer", type=int,   default=500, help="AOI buffer in metres (default 500).")
    parser.add_argument("--cloud",  type=float, default=20,  help="Max cloud %% (default 20).")
    parser.add_argument("--scale",  type=int,   default=10,  help="Pixel resolution metres (default 10).")
    parser.add_argument("--image-types", nargs="+", default=[], choices=IMAGE_TYPES, metavar="TYPE",
                        help=f"Image types to download: {IMAGE_TYPES}. Default: none (indices only).")
    parser.add_argument("--export", default="local", choices=EXPORT_TARGETS,
                        help="Export destination: local | drive | both (default: local).")
    parser.add_argument("--image-dir", default="./gee_images",
                        help="Local folder to save images (default: ./gee_images).")
    parser.add_argument("--output", default=None, help="CSV output path.")
    return parser.parse_args()


# ──────────────────────────────────────────────────────────────────────────────
# 2. GEE INIT
# ──────────────────────────────────────────────────────────────────────────────

def init_gee():
    PROJECT_ID = os.environ.get('PROJECT_ID')
    try:
        import ee
    except ImportError:
        print("ERROR: earthengine-api not installed.\n    Run: pip install earthengine-api")
        sys.exit(1)
    try:
        ee.Initialize(project=PROJECT_ID)
        print("OK   Google Earth Engine initialised.")
    except Exception:
        print("WARN Not authenticated. Running: earthengine authenticate ...")
        ee.Authenticate()
        ee.Initialize(project=PROJECT_ID)
    return ee


# ──────────────────────────────────────────────────────────────────────────────
# 3. INDEX COMPUTATION
# ──────────────────────────────────────────────────────────────────────────────

def add_indices(image, ee, index_names):
    s2 = image.divide(10000)
    aliases = {
        "BLUE":    s2.select("B2"),
        "GREEN":   s2.select("B3"),
        "RED":     s2.select("B4"),
        "REDEDGE": s2.select("B5"),
        "NIR":     s2.select("B8"),
        "SWIR1":   s2.select("B11"),
        "SWIR2":   s2.select("B12"),
    }
    for name in index_names:
        expr, _ = INDEX_REGISTRY[name]
        try:
            image = image.addBands(image.expression(expr, aliases).rename(name))
        except Exception as ex:
            print(f"  WARN Could not compute {name}: {ex}")
    return image


# ──────────────────────────────────────────────────────────────────────────────
# 4. VALUE EXTRACTION
# ──────────────────────────────────────────────────────────────────────────────

def extract_values(image, aoi, index_names, scale, ee):
    result = image.select(index_names).reduceRegion(
        reducer=ee.Reducer.mean(), geometry=aoi, scale=scale, maxPixels=1e9
    )
    return result.getInfo()


# ──────────────────────────────────────────────────────────────────────────────
# 5. LOCAL IMAGE SAVE
# ──────────────────────────────────────────────────────────────────────────────

def _download_url(url, dest_path):
    r = requests.get(url, timeout=180)
    r.raise_for_status()
    with open(dest_path, "wb") as f:
        f.write(r.content)


def save_image_locally(image, aoi, label, image_types, image_dir, scale, ee):
    os.makedirs(image_dir, exist_ok=True)
    safe = label.replace(" ", "_")

    for itype in image_types:

        if itype == "rgb":
            vis = {"bands": ["B4", "B3", "B2"], "min": 0.0, "max": 0.3, "gamma": 1.4}
            src = image.divide(10000)
            fname = os.path.join(image_dir, f"{safe}_rgb.png")

        elif itype == "falsecolor":
            vis = {"bands": ["B8", "B4", "B3"], "min": 0.0, "max": 0.5, "gamma": 1.4}
            src = image.divide(10000)
            fname = os.path.join(image_dir, f"{safe}_falsecolor.png")

        elif itype == "ndvi":
            src = image.normalizedDifference(["B8", "B4"]).rename("NDVI")
            vis = {"bands": ["NDVI"], "min": -0.2, "max": 0.8, "palette": NDVI_PALETTE}
            fname = os.path.join(image_dir, f"{safe}_ndvi.png")

        elif itype == "geotiff":
            url = image.getDownloadURL({
                "bands": ["B2", "B3", "B4", "B5", "B8", "B11", "B12"],
                "region": aoi,
                "scale": scale,
                "format": "GEO_TIFF",
            })
            fname = os.path.join(image_dir, f"{safe}_raw.tif")
            try:
                _download_url(url, fname)
                print(f"    SAVE GeoTIFF -> {fname}")
            except Exception as ex:
                print(f"    WARN GeoTIFF download failed: {ex}")
            continue

        else:
            continue

        try:
            url = src.getThumbURL({"region": aoi, "format": "png", **vis})
            _download_url(url, fname)
            print(f"    SAVE {itype.upper()} PNG -> {fname}")
        except Exception as ex:
            print(f"    WARN {itype} save failed: {ex}")


# ──────────────────────────────────────────────────────────────────────────────
# 6. GOOGLE DRIVE EXPORT
# ──────────────────────────────────────────────────────────────────────────────

def export_to_drive(image, aoi, label, image_types, drive_folder, scale, ee):
    safe = label.replace(" ", "_").replace("-", "")

    for itype in image_types:
        if itype == "rgb":
            export_img = image.divide(10000).select(["B4", "B3", "B2"])
            desc = f"{safe}_rgb"
        elif itype == "falsecolor":
            export_img = image.divide(10000).select(["B8", "B4", "B3"])
            desc = f"{safe}_falsecolor"
        elif itype == "ndvi":
            export_img = image.normalizedDifference(["B8", "B4"]).rename("NDVI")
            desc = f"{safe}_ndvi"
        elif itype == "geotiff":
            export_img = image.select(["B2", "B3", "B4", "B5", "B8", "B11", "B12"])
            desc = f"{safe}_raw"
        else:
            continue

        task = ee.batch.Export.image.toDrive(
            image=export_img,
            description=desc,
            folder=drive_folder,
            region=aoi,
            scale=scale,
            maxPixels=1e9,
            fileFormat="GeoTIFF",
        )
        task.start()
        print(f"    DRIVE Export submitted: {desc}")


# ──────────────────────────────────────────────────────────────────────────────
# 7. SCENE FETCH LOOPS
# ──────────────────────────────────────────────────────────────────────────────

def fetch_all_scenes(collection, aoi, args, ee):
    import pandas as pd
    records  = []
    img_list = collection.toList(collection.size())
    n        = img_list.size().getInfo()
    print(f"  Found {n} scenes. Extracting ...\n")

    for i in range(n):
        img       = ee.Image(img_list.get(i))
        date_str  = img.date().format("YYYY-MM-dd").getInfo()
        cloud_pct = img.get("CLOUDY_PIXEL_PERCENTAGE").getInfo()
        img       = add_indices(img, ee, args.indices)
        vals      = extract_values(img, aoi, args.indices, args.scale, ee)

        row = {"date": date_str, "cloud_pct": round(cloud_pct, 2)}
        row.update(vals)
        records.append(row)
        print(f"  [{i+1}/{n}] {date_str}  cloud={cloud_pct:.1f}%  NDVI={vals.get('NDVI', 'N/A')}")

        if args.image_types:
            if args.export in ("local", "both"):
                save_image_locally(img, aoi, date_str, args.image_types, args.image_dir, args.scale, ee)
            if args.export in ("drive", "both"):
                file_prefix = f"plot_{args.plot_id}_{date_str}"
                export_to_drive(img, aoi, file_prefix, args.image_types, DRIVE_EXPORT_FOLDER, args.scale, ee)

    return pd.DataFrame(records)


def fetch_gap_composites(collection, aoi, args, ee):
    import pandas as pd
    records  = []
    current  = datetime.strptime(args.start, "%Y-%m-%d")
    end_dt   = datetime.strptime(args.end,   "%Y-%m-%d")
    win_n    = 0

    while current <= end_dt:
        window_end = min(current + timedelta(days=args.gap - 1), end_dt)
        s     = current.strftime("%Y-%m-%d")
        e     = window_end.strftime("%Y-%m-%d")
        label = f"{s}_to_{e}"
        win_n += 1

        sub   = collection.filterDate(s, e)
        count = sub.size().getInfo()

        if count == 0:
            print(f"  [{win_n}] {s} -> {e}  (no scenes)")
        else:
            composite = sub.median()
            composite = add_indices(composite, ee, args.indices)
            vals      = extract_values(composite, aoi, args.indices, args.scale, ee)

            row = {"period_start": s, "period_end": e, "scene_count": count}
            row.update(vals)
            records.append(row)
            print(f"  [{win_n}] {s} -> {e}  scenes={count}  NDVI={vals.get('NDVI', 'N/A')}")

            if args.image_types:
                if args.export in ("local", "both"):
                    save_image_locally(composite, aoi, label, args.image_types, args.image_dir, args.scale, ee)
                if args.export in ("drive", "both"):
                  file_prefix = f"plot_{args.plot_id}_{label}"
                  export_to_drive(composite, aoi, file_prefix, args.image_types, DRIVE_EXPORT_FOLDER, args.scale, ee)

        current = window_end + timedelta(days=1)

    return pd.DataFrame(records)


# ──────────────────────────────────────────────────────────────────────────────
# 8. MAIN
# ──────────────────────────────────────────────────────────────────────────────

def main():
    args = parse_args()

    print("\nGEE - Sentinel-2 Index Fetcher + Image Downloader")
    print("-" * 58)
    print(f"  Location    : lat={args.lat}, lon={args.lon}")
    print(f"  Date range  : {args.start}  ->  {args.end}")
    print(f"  Gap         : {args.gap if args.gap else 'None (every scene)'} days")
    print(f"  Indices     : {args.indices}")
    print(f"  Image types : {args.image_types if args.image_types else 'None (indices only)'}")
    if args.image_types:
        print(f"  Export to   : {args.export}")
        if args.export in ("local", "both"):
            print(f"  Image dir   : {args.image_dir}")
        if args.export in ("drive", "both"):
            print(f"  Drive folder: {DRIVE_EXPORT_FOLDER}")

    print(f"  Buffer      : {args.buffer} m  |  Cloud: {args.cloud}%  |  Scale: {args.scale} m")
    print()

    ee = init_gee()

    # AOI
    point = ee.Geometry.Point([args.lon, args.lat])
    aoi   = point.buffer(args.buffer)

    # Sentinel-2 SR collection
    collection = (
        ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
        .filterBounds(aoi)
        .filterDate(args.start, args.end)
        .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", args.cloud))
        .sort("system:time_start")
    )

    total = collection.size().getInfo()
    if total == 0:
        print("ERROR: No scenes found. Try relaxing --cloud or widening the date range.")
        sys.exit(1)

    print(f"  Matching scenes in GEE: {total}\n")

    # Fetch
    if args.gap:
        df = fetch_gap_composites(collection, aoi, args, ee)
    else:
        df = fetch_all_scenes(collection, aoi, args, ee)

    # Display
    import pandas as pd
    pd.set_option("display.max_columns", 20)
    pd.set_option("display.width", 130)
    pd.set_option("display.float_format", "{:.4f}".format)

    print(f"\n{'='*58}")
    print(f"  RESULTS  -  {len(df)} rows x {len(df.columns)} columns")
    print(f"{'='*58}")
    print(df.to_string(index=False))

    # Save CSV
    if args.output:
        df.to_csv(args.output, index=False)
        print(f"\nCSV saved -> {args.output}")

    # Summary
    if args.image_types and args.export in ("local", "both"):
        print(f"\nImages saved -> {os.path.abspath(args.image_dir)}/")
    if args.image_types and args.export in ("drive", "both"):
        print(f"\nDrive exports submitted -> folder: '{DRIVE_EXPORT_FOLDER}' (at Drive root)")
        print("Monitor at: https://code.earthengine.google.com/tasks")

    print("\nDone.\n")


if __name__ == "__main__":
    main()
# Out:
# Writing gee_index_fetcher.py

# %% [markdown]
# ## Coodinate scripts setup -- NO need to run this

# %%
# @title
# %%writefile coordinate_scripts.py

# // Define all plot coordinates
# var plots = [
#   {id: 2, coords: [[84.832155,25.575205], [84.832196,25.575386], [84.832388,25.575348], [84.832341,25.575163]]},
#   {id: 3, coords: [[84.832352,25.57516], [84.832388,25.575348], [84.832591,25.575296], [84.832546,25.575125]]},
#   {id: 4, coords: [[84.832338,25.575025], [84.832505,25.575767], [84.833002,25.575677], [84.83283,25.574947]]},
#   {id: 5, coords: [[84.831688,25.575456], [84.831763,25.575837], [84.83216,25.575807], [84.832082,25.575386]]},
#   {id: 6, coords: [[84.830517,25.575633], [84.830593,25.576054], [84.831004,25.576054], [84.830938,25.575589]]},
#   {id: 7, coords: [[84.830586,25.575238], [84.830647,25.575743], [84.831116,25.575711], [84.831068,25.575185]]},
#   {id: 8, coords: [[84.83028,25.57506], [84.830365,25.575592], [84.831262,25.575476], [84.831166,25.57498]]},
#   {id: 9, coords: [[84.829494,25.575376], [84.829625,25.575976], [84.830161,25.575933], [84.830038,25.575356]]},
#   {id: 10, coords: [[84.829187,25.577356], [84.829364,25.5785], [84.830522,25.578425], [84.830309,25.577263]]},
#   {id: 11, coords: [[84.832613,25.585387], [84.832973,25.585387], [84.832962,25.585235], [84.8326,25.58524]]},
#   {id: 12, coords: [[84.831812,25.584481], [84.832254,25.584427], [84.83223,25.584206], [84.831742,25.584266]]},
#   {id: 13, coords: [[84.832605,25.585396], [84.832984,25.585383], [84.832955,25.585233], [84.832597,25.585236]]},
#   {id: 14, coords: [[84.832831,25.585087], [84.833051,25.585058], [84.833037,25.584829], [84.832828,25.584838]]},
#   {id: 41, coords: [[84.831356,25.568640], [84.831544,25.569559], [84.832335,25.569434], [84.832206,25.568524]]},
#   {id: 42, coords: [[84.832206,25.568524], [84.832335,25.569434], [84.833314,25.569166], [84.833195,25.568381]]},
#   {id: 43, coords: [[84.831514,25.567596], [84.831514,25.568390], [84.832266,25.568292], [84.832206,25.567489]]},
#   {id: 44, coords: [[84.828508,25.569077], [84.828705,25.569826], [84.829625,25.569862], [84.829467,25.568863]]},
#   {id: 45, coords: [[84.829467,25.568863], [84.829625,25.569862], [84.830683,25.569684], [84.830426,25.568792]]},
#   {id: 46, coords: [[84.824690,25.567079], [84.824987,25.567908], [84.825966,25.567792], [84.825758,25.566918]]},
#   {id: 47, coords: [[84.826826,25.552557], [84.827028,25.554131], [84.828412,25.553988], [84.828152,25.552414]]},
#   {id: 48, coords: [[84.830098,25.552310], [84.830545,25.553819], [84.831900,25.553910], [84.831482,25.552258]]},
#   {id: 49, coords: [[84.823626,25.555796], [84.823669,25.556888], [84.825356,25.556862], [84.825226,25.555666]]},
#   {id: 50, coords: [[84.828945,25.550086], [84.829089,25.551348], [84.830675,25.551192], [84.830401,25.550073]]},
#   {id: 51, coords: [[84.811690,25.551127], [84.811575,25.552245], [84.813060,25.551946], [84.813031,25.551127]]},
#   {id: 52, coords: [[84.820047,25.545685], [84.820742,25.547701], [84.822386,25.547116], [84.822062,25.545413]]},
#   {id: 53, coords: [[84.811888,25.546818], [84.812281,25.547991], [84.813099,25.547716], [84.812795,25.546709]]}
# ];

# // Color palette for different plots
# var colors = ['FF0000', '00FF00', '0000FF', 'FFFF00', 'FF00FF', '00FFFF',
#               'FFA500', '800080', 'FFC0CB', 'A52A2A', '808080', '000080'];

# // Create feature collection from all plots
# var features = [];
# plots.forEach(function(plot) {
#   var polygon = ee.Geometry.Polygon([plot.coords]);
#   var feature = ee.Feature(polygon, {plot_id: plot.id});
#   features.push(feature);
# });

# var allPlots = ee.FeatureCollection(features);

# // Calculate the center of all plots for initial map view
# var bounds = allPlots.geometry().bounds();
# Map.centerObject(bounds, 12);

# // Add all plots to the map with labels
# plots.forEach(function(plot, index) {
#   var polygon = ee.Geometry.Polygon([plot.coords]);
#   var color = colors[index % colors.length];

#   Map.addLayer(polygon, {color: color}, 'Plot ' + plot.id, false);

#   // Add label at centroid
#   var centroid = polygon.centroid();
#   Map.addLayer(centroid, {color: 'FFFFFF'}, 'Label ' + plot.id, false);
# });

# // Add all plots as one layer with different colors
# Map.addLayer(allPlots.style({
#   color: 'blue',
#   fillColor: '00000000',
#   width: 2
# }), {}, 'All Plots', true);

# // Print summary information
# print('Total number of plots:', plots.length);
# print('Plot IDs:', plots.map(function(p) { return p.id; }));
# print('All plots feature collection:', allPlots);

# // Optional: Add a base layer (Sentinel-2 image)
# var sentinel2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
#   .filterBounds(bounds)
#   .filterDate('2024-01-01', '2025-01-01')
#   .sort('CLOUDY_PIXEL_PERCENTAGE')
#   .first();

# Map.addLayer(sentinel2, {
#   bands: ['B4', 'B3', 'B2'],
#   min: 0,
#   max: 3000
# }, 'Sentinel-2 RGB', false);

# // Create a legend
# var legend = ui.Panel({
#   style: {
#     position: 'bottom-left',
#     padding: '8px 15px'
#   }
# });

# var legendTitle = ui.Label({
#   value: 'Plot Legend',
#   style: {
#     fontWeight: 'bold',
#     fontSize: '16px',
#     margin: '0 0 4px 0',
#     padding: '0'
#   }
# });

# legend.add(legendTitle);
# legend.add(ui.Label('Total Plots: ' + plots.length));
# legend.add(ui.Label('Click layers to toggle visibility'));

# Map.add(legend);
# Out:
# Writing coordinate_scripts.py

# %% [markdown]
# ## Plot Coordinates

# %%
# @title
import os
import subprocess
from google.colab import drive

drive.mount('/content/drive')

plots = [
  {"id": 2, "coords": [[84.832155,25.575205], [84.832196,25.575386], [84.832388,25.575348], [84.832341,25.575163]]},
  {"id": 3, "coords": [[84.832352,25.57516], [84.832388,25.575348], [84.832591,25.575296], [84.832546,25.575125]]},
  {"id": 4, "coords": [[84.832338,25.575025], [84.832505,25.575767], [84.833002,25.575677], [84.83283,25.574947]]},
  {"id": 5, "coords": [[84.831688,25.575456], [84.831763,25.575837], [84.83216,25.575807], [84.832082,25.575386]]},
  {"id": 6, "coords": [[84.830517,25.575633], [84.830593,25.576054], [84.831004,25.576054], [84.830938,25.575589]]},
  {"id": 7, "coords": [[84.830586,25.575238], [84.830647,25.575743], [84.831116,25.575711], [84.831068,25.575185]]},
  {"id": 8, "coords": [[84.83028,25.57506], [84.830365,25.575592], [84.831262,25.575476], [84.831166,25.57498]]},
  {"id": 9, "coords": [[84.829494,25.575376], [84.829625,25.575976], [84.830161,25.575933], [84.830038,25.575356]]},
  {"id": 10, "coords": [[84.829187,25.577356], [84.829364,25.5785], [84.830522,25.578425], [84.830309,25.577263]]},
  {"id": 11, "coords": [[84.832613,25.585387], [84.832973,25.585387], [84.832962,25.585235], [84.8326,25.58524]]},
  {"id": 12, "coords": [[84.831812,25.584481], [84.832254,25.584427], [84.83223,25.584206], [84.831742,25.584266]]},
  {"id": 13, "coords": [[84.832605,25.585396], [84.832984,25.585383], [84.832955,25.585233], [84.832597,25.585236]]},
  {"id": 14, "coords": [[84.832831,25.585087], [84.833051,25.585058], [84.833037,25.584829], [84.832828,25.584838]]},
  {"id": 15, "coords": [[84.832555,25.584388], [84.832775,25.584364], [84.832756,25.584137], [84.832522,25.584154]]},
  {"id": 16, "coords": [[84.828025,25.577031], [84.828160,25.578086], [84.828879,25.577993], [84.828606,25.576985]]},
  {"id": 17, "coords": [[84.827460,25.582535], [84.827548,25.582999], [84.828402,25.582956], [84.828409,25.582431]]},
  {"id": 18, "coords": [[84.827297,25.582089], [84.827460,25.582535], [84.828409,25.582431], [84.827921,25.582089]]},
  {"id": 19, "coords": [[84.829154,25.582608], [84.829174,25.583115], [84.830021,25.582999], [84.829730,25.582480]]},
  {"id": 20, "coords": [[84.828646,25.581911], [84.828930,25.582406], [84.829601,25.582382], [84.829283,25.581911]]},
  {"id": 21, "coords": [[84.827419,25.581013], [84.827460,25.580469], [84.828077,25.580377], [84.828049,25.580848]]},
  {"id": 47, "coords": [[84.826826,25.552557], [84.827028,25.554131], [84.828412,25.553988], [84.828152,25.552414]]},
  {"id": 48, "coords": [[84.830098,25.552310], [84.830545,25.553819], [84.831900,25.553910], [84.831482,25.552258]]},
  {"id": 49, "coords": [[84.823626,25.555796], [84.823669,25.556888], [84.825356,25.556862], [84.825226,25.555666]]},
  {"id": 50, "coords": [[84.828945,25.550086], [84.829089,25.551348], [84.830675,25.551192], [84.830401,25.550073]]},
  {"id": 51, "coords": [[84.811690,25.551127], [84.811575,25.552245], [84.813060,25.551946], [84.813031,25.551127]]},
  {"id": 52, "coords": [[84.820047,25.545685], [84.820742,25.547701], [84.822386,25.547116], [84.822062,25.545413]]},
  {"id": 53, "coords": [[84.811888,25.546818], [84.812281,25.547991], [84.813099,25.547716], [84.812795,25.546709]]}
]
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Sanitise the Google Drive folders

# %%
# @title
import os
import shutil

folders_to_clean = [
    '/content/drive/MyDrive/pheno_crop/sentinel_1',
    '/content/drive/MyDrive/pheno_crop/sentinel_2',
]

print("INITIATING FOLDER WIPE...")
print("=" * 50)

for folder_path in folders_to_clean:
    if os.path.exists(folder_path):
        file_count = sum(len(files) for _, _, files in os.walk(folder_path))
        print(f"Deleting {file_count} files from: {folder_path}")

        shutil.rmtree(folder_path)

        os.makedirs(folder_path, exist_ok=True)
        print(f"   Folder recreated and empty.")
    else:
        print(f"Not found (Creating fresh): {folder_path}")
        os.makedirs(folder_path, exist_ok=True)

print("=" * 50)
print("All directories are sanitized and ready for the fetch!")
# Out:
# INITIATING FOLDER WIPE...
# ==================================================
# Deleting 0 files from: /content/drive/MyDrive/pheno_crop/sentinel_1
#    Folder recreated and empty.
# Deleting 0 files from: /content/drive/MyDrive/pheno_crop/sentinel_2
#    Folder recreated and empty.
# ==================================================
# All directories are sanitized and ready for the fetch!

# %% [markdown]
# ## Sentinel-2 Fetching Script

# %%
# @title
base_dir_s2 = '/content/drive/MyDrive/pheno_crop/sentinel_2'
os.makedirs(base_dir_s2, exist_ok=True)

import os, subprocess
PROJECT_ID = userdata.get('PROJECT_ID')
my_env = os.environ.copy()
my_env['PROJECT_ID'] = PROJECT_ID

print(f"Starting batch job for {len(plots)} plots...")

# TODO: Make parameter changes according to season and get plots for all ids

for plot in plots:
    plot_id = plot['id']
    coords = plot['coords']

    # Calculate Centroid (average lat and lon)
    avg_lon = sum(c[0] for c in coords) / len(coords)
    avg_lat = sum(c[1] for c in coords) / len(coords)

    print(f"Queueing Plot {plot_id}...")

    csv_path = f"{base_dir_s2}/plot_{plot_id}_indices.csv"

    # Command array (Using a very tight 20m buffer so we don't grab neighboring fields)
    # Getting only the csv files for now!
    cmd = [
        "python", "gee_index_fetcher.py",
        "--lat", str(avg_lat),
        "--lon", str(avg_lon),
        "--start", "2024-11-01",
        "--end", "2025-04-30",
        "--buffer", "20",
        "--plot-id", str(plot_id),
        "--indices", "NDVI", "NDWI", "NDRE", "EVI", "SAVI", "MSAVI", "NDMI", "GNDVI",
        "--output", csv_path
        # "--image-types", "geotiff",
        # "--export", "drive",
    ]

    result = subprocess.run(cmd, capture_output=True, text=True, env=my_env)

    if result.returncode == 0:
        print(result.stdout)
    else:
        print(f"❌ Error on Plot {plot_id}:")
        print(result.stderr)

print("All tasks successfully submitted to Google Earth Engine!")
print(f"Check your Google Drive. CSVs are saved to: {base_dir_s2}")
print("GeoTIFF images will appear in Drive in the background as Google's servers finish processing.")
# Out:
# Starting batch job for 52 plots...
# Queueing Plot 2...
#
# GEE - Sentinel-2 Index Fetcher + Image Downloader
# ----------------------------------------------------------
#   Location    : lat=25.5752755, lon=84.83227
#   Date range  : 2024-11-01  ->  2025-04-30
#   Gap         : None (every scene) days
#   Indices     : ['NDVI', 'NDWI', 'NDRE', 'EVI', 'SAVI', 'MSAVI', 'NDMI', 'GNDVI']
#   Image types : None (indices only)
#   Buffer      : 20 m  |  Cloud: 20%  |  Scale: 10 m
#
# OK   Google Earth Engine initialised.
#   Matching scenes in GEE: 110
#
#   Found 110 scenes. Extracting ...
#
#   [1/110] 2024-11-02  cloud=3.6%  NDVI=0.6643003026514764
#   [2/110] 2024-11-02  cloud=3.4%  NDVI=0.6642092966820575
#   [3/110] 2024-11-05  cloud=8.9%  NDVI=0.30222249877937557
#   [4/110] 2024-11-05  cloud=8.8%  NDVI=0.30352652751630044
#   [5/110] 2024-11-07  cloud=0.6%  NDVI=0.7772874347035776
#   [6/110] 2024-11-07  cloud=0.6%  NDVI=0.7752370012379034
#   [7/110] 2024-11-10  cloud=1.7%  NDVI=0.6100750415973225
#   [8/110] 2024-11-10  cloud=2.0%  NDVI=0.611313061396039
#   [9/110] 2024-11-12  cloud=3.1%  NDVI=0.5740917232700101
#   [10/110] 2024-11-12  cloud=2.8%  NDVI=0.5744239496000602
#   [11/110] 2024-11-15  cloud=13.0%  NDVI=0.7451896531057568
#   [12/110] 2024-11-15  cloud=11.6%  NDVI=0.7469899619263222
#   [13/110] 2024-11-17  cloud=1.2%  NDVI=0.4954856494440364
#   [14/110] 2024-11-17  cloud=1.2%  NDVI=0.4951461905878817
#   [15/110] 2024-11-20  cloud=2.2%  NDVI=0.40550659041190984
#   [16/110] 2024-11-20  cloud=2.2%  NDVI=0.40866385901688507
#   [17/110] 2024-11-22  cloud=1.7%  NDVI=0.36326475757679877
#   [18/110] 2024-11-22  cloud=1.8%  NDVI=0.36437620934965137
#   [19/110] 2024-11-25  cloud=1.7%  NDVI=0.4170476721449621
#   [20/110] 2024-11-25  cloud=1.9%  NDVI=0.4170735963102095
#   [21/110] 2024-11-30  cloud=0.0%  NDVI=0.30030288326652066
#   [22/110] 2024-11-30  cloud=0.0%  NDVI=0.3010663639869443
#   [23/110] 2024-12-02  cloud=0.1%  NDVI=0.24630169924266937
#   [24/110] 2024-12-02  cloud=0.1%  NDVI=0.24739381075087666
#   [25/110] 2024-12-07  cloud=0.6%  NDVI=0.22770538609992666
#   [26/110] 2024-12-07  cloud=0.8%  NDVI=0.22896802815541642
#   [27/110] 2024-12-10  cloud=0.1%  NDVI=0.1689139166758956
#   [28/110] 2024-12-10  cloud=0.2%  NDVI=0.16860894913575247
# 2025-04-26    17.1500 0.1923 0.4040 0.1893 -0.0917 0.1722 0.2846 -0.4040 0.2068
# 2025-04-26    15.1300 0.1928 0.4048 0.1899 -0.0920 0.1718 0.2857 -0.4048 0.2075
#
# CSV saved -> /content/drive/MyDrive/pheno_crop/sentinel_2/plot_2_indices.csv
#
# Done.
#
#
# Queueing Plot 3...
#
# GEE - Sentinel-2 Index Fetcher + Image Downloader
# ----------------------------------------------------------
#   Location    : lat=25.57523225, lon=84.83246925
#   Date range  : 2024-11-01  ->  2025-04-30
#   Gap         : None (every scene) days
#   Indices     : ['NDVI', 'NDWI', 'NDRE', 'EVI', 'SAVI', 'MSAVI', 'NDMI', 'GNDVI']
#   Image types : None (indices only)
#   Buffer      : 20 m  |  Cloud: 20%  |  Scale: 10 m
#
# OK   Google Earth Engine initialised.
#   Matching scenes in GEE: 110
#
#   Found 110 scenes. Extracting ...
#
#   [1/110] 2024-11-02  cloud=3.6%  NDVI=0.6609958772462937
#   [2/110] 2024-11-02  cloud=3.4%  NDVI=0.6602769029567557
#   [3/110] 2024-11-05  cloud=8.9%  NDVI=0.30093945846236553
#   [4/110] 2024-11-05  cloud=8.8%  NDVI=0.30213050524925206
#   [5/110] 2024-11-07  cloud=0.6%  NDVI=0.7624068605976864
#   [6/110] 2024-11-07  cloud=0.6%  NDVI=0.7594531512302489
#   [7/110] 2024-11-10  cloud=1.7%  NDVI=0.5954660561244631
#   [8/110] 2024-11-10  cloud=2.0%  NDVI=0.596369863893843
#   [9/110] 2024-11-12  cloud=3.1%  NDVI=0.5562959425058026
#   [10/110] 2024-11-12  cloud=2.8%  NDVI=0.5556378467339845
#   [11/110] 2024-11-15  cloud=13.0%  NDVI=0.721148296996431
#   [12/110] 2024-11-15  cloud=11.6%  NDVI=0.7228262132092761
#   [13/110] 2024-11-17  cloud=1.2%  NDVI=0.4613216495550083
#   [14/110] 2024-11-17  cloud=1.2%  NDVI=0.46147241904884884
#   [15/110] 2024-11-20  cloud=2.2%  NDVI=0.3633354154205074
#   [16/110] 2024-11-20  cloud=2.2%  NDVI=0.36486536517493606
#   [17/110] 2024-11-22  cloud=1.7%  NDVI=0.34255542866955924
#   [18/110] 2024-11-22  cloud=1.8%  NDVI=0.342307188246738
#   [19/110] 2024-11-25  cloud=1.7%  NDVI=0.3812560458825756
#   [20/110] 2024-11-25  cloud=1.9%  NDVI=0.37986191242163614
#   [21/110] 2024-11-30  cloud=0.0%  NDVI=0.3272407283242729
#   [22/110] 2024-11-30  cloud=0.0%  NDVI=0.32751164895796914
#   [23/110] 2024-12-02  cloud=0.1%  NDVI=0.24582115667163187
#   [24/110] 2024-12-02  cloud=0.1%  NDVI=0.24587386996407695
#   [25/110] 2024-12-07  cloud=0.6%  NDVI=0.22591266561546366
#   [26/110] 2024-12-07  cloud=0.8%  NDVI=0.22499425214426239
#   [27/110] 2024-12-10  cloud=0.1%  NDVI=0.17144531451985862
#   [28/110] 2024-12-10  cloud=0.2%  NDVI=0.17054673925446642
#   [29/110] 2024-12-10  cloud=0.5%  NDVI=0.17688873320493284
# 2025-04-26    15.1300 0.1967 0.4070 0.1947 -0.0782 0.1785 0.2905 -0.4070 0.2122
#
# CSV saved -> /content/drive/MyDrive/pheno_crop/sentinel_2/plot_3_indices.csv
#
# Done.
#
#
# Queueing Plot 4...
#
# GEE - Sentinel-2 Index Fetcher + Image Downloader
# ----------------------------------------------------------
#   Location    : lat=25.575354, lon=84.83266875
#   Date range  : 2024-11-01  ->  2025-04-30
#   Gap         : None (every scene) days
#   Indices     : ['NDVI', 'NDWI', 'NDRE', 'EVI', 'SAVI', 'MSAVI', 'NDMI', 'GNDVI']
#   Image types : None (indices only)
#   Buffer      : 20 m  |  Cloud: 20%  |  Scale: 10 m
#
# OK   Google Earth Engine initialised.
#   Matching scenes in GEE: 110
#
#   Found 110 scenes. Extracting ...
#
#   [1/110] 2024-11-02  cloud=3.6%  NDVI=0.6733801908692989
#   [2/110] 2024-11-02  cloud=3.4%  NDVI=0.6739674235467902
#   [3/110] 2024-11-05  cloud=8.9%  NDVI=0.2944499221307675
#   [4/110] 2024-11-05  cloud=8.8%  NDVI=0.295308362394456
#   [5/110] 2024-11-07  cloud=0.6%  NDVI=0.8081843792475348
#   [6/110] 2024-11-07  cloud=0.6%  NDVI=0.8078463977509421
#   [7/110] 2024-11-10  cloud=1.7%  NDVI=0.6272060835354742
#   [8/110] 2024-11-10  cloud=2.0%  NDVI=0.6277071476199811
#   [9/110] 2024-11-12  cloud=3.1%  NDVI=0.5638890032053685
#   [10/110] 2024-11-12  cloud=2.8%  NDVI=0.5650275779080811
#   [11/110] 2024-11-15  cloud=13.0%  NDVI=0.7860223326567828
#   [12/110] 2024-11-15  cloud=11.6%  NDVI=0.7874714742991198
#   [13/110] 2024-11-17  cloud=1.2%  NDVI=0.4946530346817592
#   [14/110] 2024-11-17  cloud=1.2%  NDVI=0.4958472458785841
#   [15/110] 2024-11-20  cloud=2.2%  NDVI=0.4123478952240929
#   [16/110] 2024-11-20  cloud=2.2%  NDVI=0.41558103011359454
#   [17/110] 2024-11-22  cloud=1.7%  NDVI=0.3789595084939943
#   [18/110] 2024-11-22  cloud=1.8%  NDVI=0.3796362470911066
#   [19/110] 2024-11-25  cloud=1.7%  NDVI=0.44046825815010143
#   [20/110] 2024-11-25  cloud=1.9%  NDVI=0.4409244410171106
#   [21/110] 2024-11-30  cloud=0.0%  NDVI=0.3264892170553662
#   [22/110] 2024-11-30  cloud=0.0%  NDVI=0.3273232282943538
#   [23/110] 2024-12-02  cloud=0.1%  NDVI=0.2712281357009127
#   [24/110] 2024-12-02  cloud=0.1%  NDVI=0.2715217056917549
#   [25/110] 2024-12-07  cloud=0.6%  NDVI=0.23136899681646741
#   [26/110] 2024-12-07  cloud=0.8%  NDVI=0.23224395217757407
#   [27/110] 2024-12-10  cloud=0.1%  NDVI=0.18276010524949354
#   [28/110] 2024-12-10  cloud=0.2%  NDVI=0.1820126638170105
#   [29/110] 2024-12-10  cloud=0.5%  NDVI=0.1874809034202214
#   [30/110] 2024-12-10  cloud=0.5%  NDVI=0.18634587380174394
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sentinel-1 Fetching Script

# %%
# @title
import ee
import pandas as pd
import os

base_dir_s1 = '/content/drive/MyDrive/pheno_crop/sentinel_1'
os.makedirs(base_dir_s1, exist_ok=True)

START_DATE = '2024-11-01'
END_DATE = '2025-04-30'

print(f"Starting Sentinel-1 SAR Extraction for {len(plots)} plots...")


for plot in plots:
    plot_id = plot['id']
    print(f"Processing Plot {plot_id}...")

    # Create the exact polygon from the coordinates
    roi = ee.Geometry.Polygon(plot['coords'])

    # Load Sentinel-1 GRD (Ground Range Detected) Collection
    # Filter for standard agricultural settings (Interferometric Wide swath, ascending/descending)
    s1_collection = (ee.ImageCollection('COPERNICUS/S1_GRD')
        .filterBounds(roi)
        .filterDate(START_DATE, END_DATE)
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV'))
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))
        .filter(ee.Filter.eq('instrumentMode', 'IW')))

    # Function to extract mean VV, VH, and calculate Ratio for the plot
    def extract_sar_values(image):
        date = image.date().format('YYYY-MM-dd')

        # Calculate VH/VV Ratio (often used in phenology)
        vv = image.select('VV')
        vh = image.select('VH')
        ratio = vh.subtract(vv).rename('VH_VV_Ratio') # In dB, subtraction is equivalent to division

        img_with_ratio = image.addBands(ratio)

        # Get mean values within the plot polygon
        stats = img_with_ratio.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=roi,
            scale=10, # Sentinel-1 resolution is roughly 10m
            maxPixels=1e9
        )

        return ee.Feature(None, {
            'date': date,
            'VV': stats.get('VV'),
            'VH': stats.get('VH'),
            'VH_VV_Ratio': stats.get('VH_VV_Ratio'),
            'orbit': image.get('orbitProperties_pass') # Keep track of ascending vs descending
        })

    # Map the extraction function over the collection
    extracted_features = s1_collection.map(extract_sar_values)

    # Download the results to Colab memory
    results_list = extracted_features.getInfo()['features']

    # Clean up the output into a Pandas DataFrame
    data = []
    for feat in results_list:
        props = feat['properties']
        if props.get('VV') is not None: # Ensure data isn't null
            data.append({
                'date': props['date'],
                'VV': props['VV'],
                'VH': props['VH'],
                'VH_VV_Ratio': props['VH_VV_Ratio'],
                'orbit': props['orbit']
            })

    df = pd.DataFrame(data)

    # Sort chronologically
    if not df.empty:
        df = df.sort_values('date').reset_index(drop=True)

        csv_path = f"{base_dir_s1}/plot_{plot_id}_sar.csv"
        df.to_csv(csv_path, index=False)
        print(f"Saved {len(df)} SAR records to {csv_path}")
    else:
        print(f"No SAR data found for Plot {plot_id}")

print("SAR Extraction Complete!")
# Out:
# Starting Sentinel-1 SAR Extraction for 52 plots...
# Processing Plot 2...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_2_sar.csv
# Processing Plot 3...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_3_sar.csv
# Processing Plot 4...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_4_sar.csv
# Processing Plot 5...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_5_sar.csv
# Processing Plot 6...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_6_sar.csv
# Processing Plot 7...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_7_sar.csv
# Processing Plot 8...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_8_sar.csv
# Processing Plot 9...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_9_sar.csv
# Processing Plot 10...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_10_sar.csv
# Processing Plot 11...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_11_sar.csv
# Processing Plot 12...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_12_sar.csv
# Processing Plot 13...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_13_sar.csv
# Processing Plot 14...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_14_sar.csv
# Processing Plot 15...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_15_sar.csv
# Processing Plot 16...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_16_sar.csv
# Processing Plot 17...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_17_sar.csv
# Processing Plot 18...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_18_sar.csv
# Processing Plot 19...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_19_sar.csv
# Processing Plot 20...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_20_sar.csv
# Processing Plot 21...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_21_sar.csv
# Processing Plot 22...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_22_sar.csv
# Processing Plot 23...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_23_sar.csv
# Processing Plot 24...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_24_sar.csv
# Processing Plot 25...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_25_sar.csv
# Processing Plot 26...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_26_sar.csv
# Processing Plot 27...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_27_sar.csv
# Processing Plot 28...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_28_sar.csv
# Processing Plot 29...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_29_sar.csv
# Processing Plot 30...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_30_sar.csv
# Processing Plot 31...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_31_sar.csv
# Processing Plot 32...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_32_sar.csv
# Processing Plot 33...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_33_sar.csv
# Processing Plot 34...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_34_sar.csv
# Processing Plot 35...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_35_sar.csv
# Processing Plot 36...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_36_sar.csv
# Processing Plot 37...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_37_sar.csv
# Processing Plot 38...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_38_sar.csv
# Processing Plot 39...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_39_sar.csv
# Processing Plot 40...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_40_sar.csv
# Processing Plot 41...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_41_sar.csv
# Processing Plot 42...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_42_sar.csv
# Processing Plot 43...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_43_sar.csv
# Processing Plot 44...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_44_sar.csv
# Processing Plot 45...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_45_sar.csv
# Processing Plot 46...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_46_sar.csv
# Processing Plot 47...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_47_sar.csv
# Processing Plot 48...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_48_sar.csv
# Processing Plot 49...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_49_sar.csv
# Processing Plot 50...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_50_sar.csv
# Processing Plot 51...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_51_sar.csv
# Processing Plot 52...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_52_sar.csv
# Processing Plot 53...
# Saved 43 SAR records to /content/drive/MyDrive/pheno_crop/sentinel_1/plot_53_sar.csv
# SAR Extraction Complete!

# %% [markdown]
# ## Folder structure verification inside Google Drive

# %%
# @title
import os
from collections import Counter

def verify_dataset(base_paths):
    print("VERIFYING DATASET STRUCTURE...")
    print("=" * 60)

    total_dataset_size = 0
    total_dataset_files = 0

    for base_path in base_paths:
        if not os.path.exists(base_path):
            print(f"Not found: {base_path} (Skipping)")
            continue

        for root, dirs, files in os.walk(base_path):
            # Calculate folder size
            folder_size = sum(os.path.getsize(os.path.join(root, f)) for f in files)
            total_dataset_size += folder_size
            total_dataset_files += len(files)

            # Count file extensions
            ext_counts = Counter(os.path.splitext(f)[1].lower() for f in files)

            # Print tree structure
            level = root.replace(base_path, '').count(os.sep)
            indent = ' ' * 4 * level
            folder_name = os.path.basename(root) if root != base_path else os.path.basename(base_path)

            print(f"{indent} {folder_name}/  [{len(files)} files | {folder_size / (1024*1024):.2f} MB]")

            if files:
                # Print file breakdown
                for ext, count in ext_counts.items():
                    ext_name = ext if ext else "no_extension"
                    print(f"{indent}    ├── {count} {ext_name} files")

                # Show first 2 examples to verify naming convention
                examples = sorted(files)
                if len(files) >= 3:
                    examples_str = f"{examples[0]}, {examples[1]}, {examples[2]}, ..."
                else:
                    examples_str = ", ".join(examples)
                print(f"{indent}    └── Examples: {examples_str}\n")
            else:
                print(f"{indent}    └── (Empty folder)\n")

    print("=" * 60)
    print(f"Total Dataset Files: {total_dataset_files}")
    print(f"Total Dataset Size:  {total_dataset_size / (1024*1024):.2f} MB")

paths_to_check = [
    '/content/drive/MyDrive/pheno_crop',
]

verify_dataset(paths_to_check)
# Out:
# VERIFYING DATASET STRUCTURE...
# ============================================================
#  pheno_crop/  [1 files | 0.07 MB]
#     ├── 1 .csv files
#     └── Examples: ground_truth.csv
#
#      sentinel_1/  [3 files | 0.01 MB]
#         ├── 3 .csv files
#         └── Examples: plot_2_sar.csv, plot_3_sar.csv, ...
#
#      sentinel_2/  [38 files | 0.14 MB]
#         ├── 35 .tif files
#         ├── 3 .csv files
#         └── Examples: plot_2_20241102_raw (1).tif, plot_2_20241102_raw.tif, ...
#
# ============================================================
# Total Dataset Files: 42
# Total Dataset Size:  0.23 MB

# %% [markdown]
# ---

# %% [markdown]
# ### Ground Truth verification

# %%
# @title
import os
import pandas as pd

def show_ground_truth(gdrive_base):
    csv_path = os.path.join(gdrive_base, "pheno_crop", "ground_truth.csv")
    print("Checking path:", csv_path)

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"File not found: {csv_path}")

    df = pd.read_csv(csv_path)
    print("Loaded ground_truth.csv")
    print("Shape:", df.shape)
    print("\n--- Head ---")
    print(df.head())
    print("\n---Tail---")
    print(df.tail())
    print("\n--- Dtypes ---")
    print(df.dtypes)

if __name__ == "__main__":
    drive_root = "/content/drive/MyDrive"
    show_ground_truth(drive_root)
# Out:
# Checking path: /content/drive/MyDrive/pheno_crop/ground_truth.csv
# Loaded ground_truth.csv
# Shape: (1484, 8)
#
# --- Head ---
#    plot_id        date      NDVI      SAVI      NDWI  days  stage_code  \
# 0        1  2024-12-27  0.194458  0.291624 -0.321014     0           1
# 1        1  2025-01-11  0.229301  0.343850 -0.316666    15           1
# 2        1  2025-01-19  0.255466  0.383110 -0.312052    23           1
# 3        1  2025-01-26  0.280332  0.420385 -0.313757    30           1
# 4        1  2025-01-29  0.336990  0.505331 -0.331553    33           2
#
#   stage_name
# 0   Seedling
# 1   Seedling
# 2   Seedling
# 3   Seedling
# 4  Tillering
#
# ---Tail---
#       plot_id        date      NDVI     SAVI      NDWI  days  stage_code  \
# 1479       54  2025-03-30  0.289850  0.43470 -0.423250    93           4
# 1480       54  2025-04-01  0.263925  0.39585 -0.408875    95           4
# 1481       54  2025-04-06  0.226950  0.34040 -0.368850   100           4
# 1482       54  2025-04-09  0.197550  0.29630 -0.313600   103           4
# 1483       54  2025-04-11  0.205150  0.30770 -0.330500   105           4
#
#      stage_name
# 1479   Ripening
# 1480   Ripening
# 1481   Ripening
# 1482   Ripening
# 1483   Ripening
#
# --- Dtypes ---
# plot_id         int64
# date           object
# NDVI          float64
# SAVI          float64
# NDWI          float64
# days            int64
# stage_code      int64
# stage_name     object
# dtype: object

# %% [markdown]
# ### To clear the active tasks in GEE

# %%
# @title
# # @title
# print("Fetching active tasks...")
# tasks = ee.batch.Task.list()
# canceled_count = 0

# for task in tasks:
#     if task.state in ['READY', 'RUNNING']:
#         task.cancel()
#         canceled_count += 1
#         print(f"Canceled task: {task.config.get('description', 'Unknown')} (was {task.state})")

# if canceled_count == 0:
#     print("No active tasks found. You are clear!")
# else:
#     print(f"\nSuccessfully wiped {canceled_count} tasks from the queue.")
# Out:
# Fetching active tasks...
# No active tasks found. You are clear!

# %% [markdown]
# # PyTorch Dataset Setup

# %%
# @title
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

class PhenologyDataset(Dataset):
    def __init__(self, gt_path, s1_dir, s2_dir, plot_ids, lookback_days=90, max_seq_len=30):
        """
        gt_path: Path to ground_truth.csv
        s1_dir: Directory with Sentinel-1 CSVs
        s2_dir: Directory with Sentinel-2 CSVs
        plot_ids: List of plot IDs to use (e.g., [2, 3, 4])
        lookback_days: How many days of history to feed the model
        max_seq_len: Padding length for the tensors
        """
        print("Initializing PyTorch Dataset...")
        self.lookback_days = lookback_days
        self.max_seq_len = max_seq_len

        # Load and filter Ground Truth
        self.gt = pd.read_csv(gt_path)
        self.gt['date'] = pd.to_datetime(self.gt['date'])
        self.gt = self.gt[self.gt['plot_id'].isin(plot_ids)].reset_index(drop=True)

        # Pre-load satellite CSVs into fast memory dictionaries
        self.s1_data = {}
        self.s2_data = {}

        for pid in plot_ids:
            # S1 Load
            s1_path = os.path.join(s1_dir, f"plot_{pid}_sar.csv")
            if os.path.exists(s1_path):
                df1 = pd.read_csv(s1_path)
                df1['date'] = pd.to_datetime(df1['date'])
                self.s1_data[pid] = df1

            # S2 Load
            s2_path = os.path.join(s2_dir, f"plot_{pid}_indices.csv")
            if os.path.exists(s2_path):
                df2 = pd.read_csv(s2_path)
                df2['date'] = pd.to_datetime(df2['date'])
                self.s2_data[pid] = df2

        print(f"Dataset ready! Found {len(self.gt)} Ground Truth events for the requested plots.")

    def __len__(self):
        return len(self.gt)

    def __getitem__(self, idx):
        # 1. The Target Event
        row = self.gt.iloc[idx]
        target_date = row['date']
        plot_id = row['plot_id']
        label = row['stage_code'] # What we want to predict

        start_date = target_date - pd.Timedelta(days=self.lookback_days)

        # --- PROCESS SENTINEL-1 (RADAR) ---
        s1_df = self.s1_data.get(plot_id, pd.DataFrame())
        s1_tensor = torch.zeros((self.max_seq_len, 3), dtype=torch.float32)
        s1_days_tensor = torch.zeros((self.max_seq_len,), dtype=torch.float32)

        if not s1_df.empty:
            mask = (s1_df['date'] > start_date) & (s1_df['date'] <= target_date)
            valid_s1 = s1_df[mask]
            if len(valid_s1) > 0:
                features = valid_s1[['VV', 'VH', 'VH_VV_Ratio']].values
                # Calculate how many days ago the reading was taken (Crucial for L-TAE/Time-Aware models)
                days_ago = (target_date - valid_s1['date']).dt.days.values

                seq_len = min(len(features), self.max_seq_len)
                s1_tensor[-seq_len:] = torch.tensor(features[-seq_len:], dtype=torch.float32)
                s1_days_tensor[-seq_len:] = torch.tensor(days_ago[-seq_len:], dtype=torch.float32)

        # --- PROCESS SENTINEL-2 (OPTICAL) ---
        s2_df = self.s2_data.get(plot_id, pd.DataFrame())
        s2_tensor = torch.zeros((self.max_seq_len, 6), dtype=torch.float32)
        s2_days_tensor = torch.zeros((self.max_seq_len,), dtype=torch.float32)

        if not s2_df.empty:
            mask = (s2_df['date'] > start_date) & (s2_df['date'] <= target_date)
            valid_s2 = s2_df[mask]
            if len(valid_s2) > 0:
                # Include cloud_pct so the model learns to ignore bad days!
                features = valid_s2[['NDVI', 'NDWI', 'NDRE', 'EVI', 'SAVI', 'cloud_pct']].values
                days_ago = (target_date - valid_s2['date']).dt.days.values

                seq_len = min(len(features), self.max_seq_len)
                s2_tensor[-seq_len:] = torch.tensor(features[-seq_len:], dtype=torch.float32)
                s2_days_tensor[-seq_len:] = torch.tensor(days_ago[-seq_len:], dtype=torch.float32)

        # Return a dictionary of the separated, asynchronous data
        return {
            's1_features': s1_tensor,
            's1_days_ago': s1_days_tensor,    # How many days before target date the S1 reading happened
            's2_features': s2_tensor,
            's2_days_ago': s2_days_tensor,    # How many days before target date the S2 reading happened
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# @title
# Try running this to see if it loads your test data successfully:

gt_path = '/content/drive/MyDrive/pheno_crop/ground_truth.csv'
s1_dir = '/content/drive/MyDrive/pheno_crop/sentinel_1'
s2_dir = '/content/drive/MyDrive/pheno_crop/sentinel_2'

test_dataset = PhenologyDataset(gt_path, s1_dir, s2_dir, plot_ids=[2, 3, 4], lookback_days=90)
sample = test_dataset[0]

print("\n--- Tensor Shapes ---")
print("S1 Features:", sample['s1_features'].shape)
print("S2 Features:", sample['s2_features'].shape)
print("Label:", sample['label'])
# Out:
# Initializing PyTorch Dataset...
# Dataset ready! Found 84 Ground Truth events for the requested plots.
#
# --- Tensor Shapes ---
# S1 Features: torch.Size([30, 3])
# S2 Features: torch.Size([30, 6])
# Label: tensor(1)

# %% [markdown]
# # Data Verification

# %%
# @title
import torch

def verify_dataset_health(dataset):
    print("INITIATING DATASET HEALTH CHECK...")
    print("=" * 60)

    total_samples = len(dataset)
    labels = []

    # Trackers for bad data
    nan_count = 0
    empty_s1_count = 0
    empty_s2_count = 0

    for i in range(total_samples):
        sample = dataset[i]

        # 1. Collect labels to check class balance
        labels.append(sample['label'].item())

        # 2. Check for NaNs or Infs (The silent killers of Neural Networks)
        if torch.isnan(sample['s1_features']).any() or torch.isnan(sample['s2_features']).any():
            nan_count += 1

        # 3. Check for completely empty sequences (meaning no satellite flew over in the last 90 days)
        if torch.max(sample['s1_features']) == 0 and torch.min(sample['s1_features']) == 0:
            empty_s1_count += 1
        if torch.max(sample['s2_features']) == 0 and torch.min(sample['s2_features']) == 0:
            empty_s2_count += 1

    # --- Print Global Health Stats ---
    print(f"Global Dataset Stats (Total Events: {total_samples})")
    print(f"  NaN/Inf Corrupted Samples: {nan_count}")
    print(f"  Samples with ZERO Radar history: {empty_s1_count}")
    print(f"  Samples with ZERO Optical history: {empty_s2_count}")

    from collections import Counter
    class_dist = Counter(labels)
    print(f"  Class Distribution: {dict(class_dist)}")

    print("\n" + "=" * 60)
    print("DEEP DIVE: WHAT THE NEURAL NETWORK ACTUALLY SEES")
    print("=" * 60)

    # Let's grab a random sample deep in the season (e.g., sample #40)
    test_idx = min(40, total_samples - 1)
    sample = dataset[test_idx]

    print(f"Target Label to Predict: Stage {sample['label'].item()}")

    # Filter out the padding (the zeros) so we only see the real readings
    real_s1_mask = sample['s1_days_ago'] > 0
    real_s2_mask = sample['s2_days_ago'] > 0

    actual_s1_readings = sample['s1_features'][real_s1_mask]
    actual_s1_days = sample['s1_days_ago'][real_s1_mask]

    actual_s2_readings = sample['s2_features'][real_s2_mask]
    actual_s2_days = sample['s2_days_ago'][real_s2_mask]

    print(f"\nRADAR BRANCH (Sentinel-1)")
    print(f"  Found {len(actual_s1_readings)} readings in the 90-day lookback window.")
    if len(actual_s1_days) > 0:
        print(f"  Days ago readings were taken: {actual_s1_days.numpy().astype(int)}")
        print(f"  Latest VV/VH/Ratio values:    {np.round(actual_s1_readings[-1].numpy(), 3)}")

    print(f"\nOPTICAL BRANCH (Sentinel-2)")
    print(f"  Found {len(actual_s2_readings)} readings in the 90-day lookback window.")
    if len(actual_s2_days) > 0:
        print(f"  Days ago readings were taken: {actual_s2_days.numpy().astype(int)}")
        print(f"  Latest NDVI (col 0) value:    {np.round(actual_s2_readings[-1][0].numpy(), 3)}")
        print(f"  Latest Cloud % (col 5):       {np.round(actual_s2_readings[-1][5].numpy(), 1)}%")

# Run the verifier
verify_dataset_health(test_dataset)
# Out:
# 🩺 INITIATING DATASET HEALTH CHECK...
# ============================================================
# Global Dataset Stats (Total Events: 84)
#   NaN/Inf Corrupted Samples: 0
#   Samples with ZERO Radar history: 0
#   Samples with ZERO Optical history: 0
#   Class Distribution: {1: 8, 2: 14, 3: 18, 4: 43, 0: 1}
#
# ============================================================
# DEEP DIVE: WHAT THE NEURAL NETWORK ACTUALLY SEES
# ============================================================
# Target Label to Predict: Stage 3
#
# RADAR BRANCH (Sentinel-1)
#   Found 20 readings in the 90-day lookback window.
#   Days ago readings were taken: [87 80 75 68 63 60 56 51 48 44 39 36 32 27 24 20 15 12  8  3]
#   Latest VV/VH/Ratio values:    [ -9.563 -17.446  -7.883]
#
# OPTICAL BRANCH (Sentinel-2)
#   Found 28 readings in the 90-day lookback window.
#   Days ago readings were taken: [63 63 58 58 43 43 35 35 28 28 25 25 23 23 20 20 15 15 13 13 10 10  8  8
#   5  5  3  3]
#   Latest NDVI (col 0) value:    0.4059999883174896
#   Latest Cloud % (col 5):       0.0%

# %% [markdown]
# # Model Architecture

# %%
# @title
import torch
import torch.nn as nn
import torch.nn.functional as F

# ---------------------------------------------------------
# 1. OPTICAL BRANCH: Time-Aware Attention (L-TAE Inspired)
# ---------------------------------------------------------
class OpticalAttentionBranch(nn.Module):
    def __init__(self, in_features=6, embed_dim=64):
        super().__init__()
        # Project our 6 Sentinel-2 features (NDVI, cloud_pct, etc.) into a richer 64-D space
        self.feature_extractor = nn.Linear(in_features, embed_dim)

        # The Attention Mechanism (Query, Key, Value)
        # We will use a MultiheadAttention to let the model decide which days matter most
        self.attention = nn.MultiheadAttention(embed_dim, num_heads=4, batch_first=True)

        # A positional embedding layer to inject the "days_ago" into the math
        # We assume a maximum lookback of 120 days.
        self.time_embed = nn.Embedding(120, embed_dim)

    def forward(self, x, days_ago):
        # x shape: [Batch, Seq_Len, 6]
        # days_ago shape: [Batch, Seq_Len]

        # 1. Extract rich features
        feats = self.feature_extractor(x) # [Batch, Seq_Len, 64]

        # 2. Add time context!
        # Clamp days_ago to max 119 to prevent embedding out-of-bounds errors
        days_clamped = torch.clamp(days_ago.long(), 0, 119)
        time_context = self.time_embed(days_clamped) # [Batch, Seq_Len, 64]

        # Combine features with their exact point in time
        feats_with_time = feats + time_context

        # 3. Apply Self-Attention (Let the model weigh the cloudy vs clear days)
        attn_out, _ = self.attention(feats_with_time, feats_with_time, feats_with_time)

        # 4. Global Average Pooling (Collapse the sequence into a single 64-D summary vector)
        summary_vector = torch.mean(attn_out, dim=1) # [Batch, 64]

        return summary_vector

# ---------------------------------------------------------
# 2. RADAR BRANCH: 1D Convolutional Neural Network
# ---------------------------------------------------------
class RadarCNNBranch(nn.Module):
    def __init__(self, in_features=3, out_dim=64):
        super().__init__()
        # Conv1D expects shape: [Batch, Channels, Seq_Len]
        self.conv1 = nn.Conv1d(in_channels=in_features, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=out_dim, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.AdaptiveAvgPool1d(1) # Forces the output to be [Batch, 64, 1]

    def forward(self, x):
        # Input x shape from dataset: [Batch, Seq_Len, 3]
        # PyTorch Conv1d needs the features in the middle: [Batch, 3, Seq_Len]
        x = x.transpose(1, 2)

        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))

        # Collapse the temporal dimension
        x = self.pool(x) # [Batch, 64, 1]
        summary_vector = x.squeeze(2) # [Batch, 64]

        return summary_vector

# ---------------------------------------------------------
# 3. THE FUSION NETWORK (The Brain)
# ---------------------------------------------------------
class DualStreamPhenologyNet(nn.Module):
    def __init__(self, num_classes=5):
        super().__init__()

        self.optical_branch = OpticalAttentionBranch(in_features=6, embed_dim=64)
        self.radar_branch = RadarCNNBranch(in_features=3, out_dim=64)

        # FUSION HEAD: Takes 64 from Optical + 64 from Radar = 128 Total
        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3), # Prevents overfitting
            nn.Linear(64, num_classes)
        )

    def forward(self, s1_feats, s1_days, s2_feats, s2_days):
        # 1. Get summary from Radar
        radar_summary = self.radar_branch(s1_feats) # [Batch, 64]

        # 2. Get summary from Optical
        optical_summary = self.optical_branch(s2_feats, s2_days) # [Batch, 64]

        # 3. Concatenate (LATE FUSION)
        fused_features = torch.cat([radar_summary, optical_summary], dim=1) # [Batch, 128]

        # 4. Final Prediction Logits
        logits = self.classifier(fused_features) # [Batch, 5]

        return logits

# --- Quick Test Code ---
print("Model Architecture Defined!")
model = DualStreamPhenologyNet(num_classes=5)

# Simulate a "dummy batch" of 2 fields to make sure the math flows through correctly
dummy_s1 = torch.rand(2, 30, 3)    # 2 fields, 30 days, 3 features
dummy_s1_days = torch.randint(0, 90, (2, 30))
dummy_s2 = torch.rand(2, 30, 6)    # 2 fields, 30 days, 6 features
dummy_s2_days = torch.randint(0, 90, (2, 30))

output = model(dummy_s1, dummy_s1_days, dummy_s2, dummy_s2_days)
print(f"Output Shape: {output.shape} -> [Batch Size, Num Classes]")
# Out:
# Model Architecture Defined!
# Output Shape: torch.Size([2, 5]) -> [Batch Size, Num Classes]

# %% [markdown]
# # Training the Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np

def train_model(dataset, model, epochs=50, batch_size=16, learning_rate=0.001):
    print("PREPARING TO TRAIN DUAL-STREAM PHENOLOGY NET...")

    # 1. Create the PyTorch DataLoader (handles batching and shuffling)
    # We shuffle so the model doesn't just memorize the order of the fields
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # 2. Calculate Dynamic Class Weights to handle the imbalance
    print("Calculating Class Weights to balance Stage 0 vs Stage 4...")
    all_labels = [dataset[i]['label'].item() for i in range(len(dataset))]
    class_counts = torch.bincount(torch.tensor(all_labels), minlength=5)

    # Avoid division by zero if a class is completely missing
    class_counts = torch.where(class_counts == 0, torch.tensor(1), class_counts)
    class_weights = len(all_labels) / (5.0 * class_counts.float())

    print(f"   Weights applied: {np.round(class_weights.numpy(), 2)}")

    # 3. Define the Loss Function and Optimizer
    # CrossEntropyLoss is the standard for multi-class classification
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # 4. The Training Loop
    print("\nSTARTING TRAINING LOOP...")
    print("=" * 60)

    for epoch in range(epochs):
        model.train() # Set model to training mode
        running_loss = 0.0
        correct_predictions = 0
        total_samples = 0

        for batch in dataloader:
            # Unpack the batch dictionary
            s1_feats = batch['s1_features']
            s1_days  = batch['s1_days_ago']
            s2_feats = batch['s2_features']
            s2_days  = batch['s2_days_ago']
            labels   = batch['label']

            # Step 1: Zero the gradients (clear old math)
            optimizer.zero_grad()

            # Step 2: Forward Pass (Predict)
            logits = model(s1_feats, s1_days, s2_feats, s2_days)

            # Step 3: Calculate Error (Loss)
            loss = criterion(logits, labels)

            # Step 4: Backward Pass (Learn)
            loss.backward()
            optimizer.step()

            # --- Tracking metrics for printing ---
            running_loss += loss.item() * labels.size(0)

            # Figure out which class the model guessed (the highest probability)
            _, predicted_classes = torch.max(logits, 1)
            correct_predictions += (predicted_classes == labels).sum().item()
            total_samples += labels.size(0)

        # Calculate epoch statistics
        epoch_loss = running_loss / total_samples
        epoch_acc = (correct_predictions / total_samples) * 100

        # Print progress every 5 epochs
        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch [{epoch+1:02d}/{epochs}] | Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.2f}%")

    print("=" * 60)
    print("TRAINING COMPLETE!")
    return model

# ---------------------------------------------------------
# EXECUTE THE TRAINING
# ---------------------------------------------------------
# Ensure your 'test_dataset' and 'model' variables from the previous cells are in memory

# Re-initialize a fresh model just to be safe
fused_model = DualStreamPhenologyNet(num_classes=5)

# Train the model!
trained_model = train_model(test_dataset, fused_model, epochs=50, batch_size=16, learning_rate=0.001)
# Out:
# PREPARING TO TRAIN DUAL-STREAM PHENOLOGY NET...
# ⚖️ Calculating Class Weights to balance Stage 0 vs Stage 4...
#    Weights applied: [16.8   2.1   1.2   0.93  0.39]
#
# STARTING TRAINING LOOP...
# ============================================================
# Epoch [01/50] | Loss: 1.6754 | Accuracy: 41.67%
# Epoch [05/50] | Loss: 1.0435 | Accuracy: 75.00%
# Epoch [10/50] | Loss: 0.7014 | Accuracy: 79.76%
# Epoch [15/50] | Loss: 0.8448 | Accuracy: 75.00%
# Epoch [20/50] | Loss: 0.6758 | Accuracy: 80.95%
# Epoch [25/50] | Loss: 0.5957 | Accuracy: 78.57%
# Epoch [30/50] | Loss: 0.6954 | Accuracy: 73.81%
# Epoch [35/50] | Loss: 0.5784 | Accuracy: 83.33%
# Epoch [40/50] | Loss: 0.5913 | Accuracy: 79.76%
# Epoch [45/50] | Loss: 0.5346 | Accuracy: 84.52%
# Epoch [50/50] | Loss: 0.5850 | Accuracy: 78.57%
# ============================================================
# TRAINING COMPLETE!
